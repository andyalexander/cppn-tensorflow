# %%
# %run -i sampler.py
sampler = Sampler(z_dim = 8, c_dim = 1, scale = 5.0, net_size = 32)

# %%
z1 = sampler.generate_z()

# %%
# dat = sampler.generate(z1, x_dim=2304, y_dim=1440)
dat = sampler.generate(z1)

sampler.show_image(dat)

# %%
sampler.reinit()
z1 = sampler.generate_z()
dat2 = sampler.generate(z1, x_dim=10500, y_dim=7000)
sampler.show_image(dat2)

# %%
sampler.save_png(dat, 'img1.png')

# %%
sampler.save_png(dat2, 'img2.png')
